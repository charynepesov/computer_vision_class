# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
# odev1 resmin kirmizi kanalini yuzde 40 azalt

img = cv2.imread('DATA/8_pepber.jpg')
#cvtColor(src, code[, dst[, dstCn]]) -> dst
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
imgR = np.copy(img)
imgG = np.copy(img)

# %%
plt.imshow(imgR)

# %%
imgR[:,:,0]
# Out:
# array([[238, 167, 154, ..., 121, 126, 130],
#        [234, 161, 150, ..., 117, 122, 125],
#        [234, 160, 148, ..., 115, 120, 123],
#        ...,
#        [226,  43,  16, ...,   5,   4,   3],
#        [218,  36,  11, ...,   4,   4,   4],
#        [228,  47,  22, ...,  23,  24,  25]], dtype=uint8)

# %%
#yontem 1
i = 0
for row in imgR[:, :, 0]:
    j = 0
    for col in row:
        imgR[i, j] = int(col * 0.6)
        j += 1
    i += 1

# %%
#yontem 2
for row in range(len(imgR[:, 0, 0])):
    for col in range(row):
        imgR[row, col] = int(imgR[row, col] * 0.6)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 2>()
#       2 for row in range(len(imgR[:, 0, 0])):
#       3     for col in range(row):
# ----> 4         imgR[row, col] = int(imgR[row, col] * 0.6)
#
# TypeError: only size-1 arrays can be converted to Python scalars

# %%
imgR[:,:,0]
# Out:
# array([[85, 60, 55, ..., 43, 45, 46],
#        [84, 57, 54, ..., 42, 43, 45],
#        [84, 57, 52, ..., 41, 43, 43],
#        ...,
#        [81, 15,  5, ...,  1,  1,  0],
#        [78, 12,  3, ...,  1,  1,  1],
#        [81, 16,  7, ...,  7,  8,  9]], dtype=uint8)

# %%
plt.subplot(1, 2, 1)
plt.imshow(img)
plt.subplot(1, 2, 2)
plt.imshow(imgR)

# %%
imgROI = img[:5,:5,0]

# %%
print(imgROI)
# Out:
# [[238 167 154 146 140]
#  [234 161 150 142 134]
#  [234 160 148 139 130]
#  [234 160 146 137 127]
#  [234 158 141 132 124]]

# %%
for row in imgROI[:, :]:
    print(row)
# Out:
# [238 167 154 146 140]
# [234 161 150 142 134]
# [234 160 148 139 130]
# [234 160 146 137 127]
# [234 158 141 132 124]

# %%
imgROI[0,0] = int(imgROI[0,0] * 0.6)

# %%
print(imgROI)
# Out:
# [[142 167 154 146 140]
#  [234 161 150 142 134]
#  [234 160 148 139 130]
#  [234 160 146 137 127]
#  [234 158 141 132 124]]

# %%
i=0
for row in imgROI[:, :]:
    j=0
    for col in row:
        imgROI[i, j] = int(col * 0.6)
        j += 1
    i += 1

# %%
print(imgROI)
# Out:
# [[ 5 12 11 10 10]
#  [30 20 19 18 16]
#  [30 20 18 17 16]
#  [30 20 18 17 16]
#  [30 19 18 16 15]]
