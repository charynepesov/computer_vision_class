# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv.imread('DATA/10_pubg.jpg')

# %%
# blur(src, ksize[, dst[, anchor[, borderType]]]) -> dst
cv.blur(img, ksize=(150,150))
# Out:
# array([[[141, 132, 112],
#         [141, 132, 112],
#         [141, 132, 112],
#         ...,
#         [132, 121,  98],
#         [132, 121,  98],
#         [132, 121,  98]],
#
#        [[141, 132, 112],
#         [141, 132, 112],
#         [141, 132, 112],
#         ...,
#         [132, 121,  98],
#         [132, 121,  98],
#         [132, 121,  98]],
#
#        [[141, 132, 112],
#         [141, 132, 112],
#         [141, 132, 112],
#         ...,
#         [132, 121,  98],
#         [132, 121,  98],
#         [132, 121,  98]],
#
#        ...,
#
#        [[ 42,  42,  38],
#         [ 42,  42,  38],
#         [ 42,  42,  38],
#         ...,
#         [ 54,  76,  79],
#         [ 54,  76,  79],
#         [ 54,  76,  79]],
#
#        [[ 41,  42,  38],
#         [ 41,  42,  38],
#         [ 41,  42,  38],
#         ...,
#         [ 54,  76,  79],
#         [ 54,  76,  79],
#         [ 54,  76,  79]],
#
#        [[ 41,  42,  38],
#         [ 41,  42,  38],
#         [ 41,  42,  38],
# ...

# %%
plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
