# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
imgGray = cv2.imread('DATA/3_opencv-logo.png', cv2.IMREAD_GRAYSCALE)
dimensions = imgGray.shape
dimensions
# Out:
# (185, 150)

# %%
plt.imshow(imgGray, cmap='gray')

# %%
imgGray[6, 75] = 0
plt.imshow(imgGray, cmap='gray')
