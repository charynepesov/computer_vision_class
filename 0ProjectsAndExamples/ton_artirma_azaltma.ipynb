# %%
import cv2
import matplotlib.pyplot as plt

resim = cv2.imread('1_ayasofya.jpg')
resim = cv2.cvtColor(resim, cv2.COLOR_BGR2RGB)

dikey, yatay, kanal = resim.shape
resim[:,:int(yatay/2), 0] = 0
resim[:,int(yatay/2):, 0] = 255
resim[:,int(yatay/2):, 1] = 255
resim[:,int(yatay/2):, 2] = 255


plt.imshow(resim)
resim.shape
# Out:
# (533, 800, 3)
