# %%
#yesil kanalinda 150 ile 200 arasinda hicbir piksel degeri olmasin

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = plt.imread('DATA/8_pepber.jpg')
plt.imshow(img)
img.shape
# Out:
# (1024, 1024, 3)

# %%
red = img[:, :, 0]
green = img[:,:,1]
blue = img[:, :, 2]
green.shape
plt.imshow(green)

# %%
imgNew = np.copy(img)
for row in imgNew[:, :, 0]:
    for col in row:
        if(col > 150):
            col = 0

# %%
imgNew[10,10,1]
# Out:
# 196

# %%
for row in green:
    #print(row)
    for col in row:
        #print(col)
        if(col > 150 or col < 200):
            print(col)
            col = 10
imgNew = cv2.merge([red, green, blue])

# %%
plt.subplot(121)
plt.imshow(img)
plt.subplot(122)
plt.imshow(imgNew)
#plt.imsave('imgNew.jpg', imgNew)
