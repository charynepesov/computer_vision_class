# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

img = cv2.imread('1_ayasofya.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# img_red = img[:,0]
# img_green = img[:,:,1]
# img_blue = img[:,:,2]
# img2 = np.copy(img)
# img2 = cv2.resize(img, (1920,1080), img)
#img = cv2.flip(img, 1)
# cv2.rectangle(img, (300,100), (550,230), (255,0,0), 8, cv2.LINE_AA, 0)
# cv2.circle(img, (400,400), 50, (255,0,0), cv2.FILLED)
# cv2.line(img, (0,300), (750,300), (255,0,0), 10)


plt.imshow(img)
